# %% [markdown]
# # KNN Algorithm in Supervised Machine Learning
# # KNeighborsClassifier of sklearn library for this one

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
X = np.array ([
    [1, 3500],
    [2, 3200],
    [3, 3000],
    [4, 2500],
    [5, 2300],
    [6, 2000],
    [7, 2200],
    [2, 3700],
])
y = ['Unfit','Unfit','Unfit','Fit','Fit','Fit','Fit','Unfit']

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_person = [[4.5, 2600]]
pred = model.predict(new_person)
print ("Predicted Result:", pred[0])
# Out:
# Predicted Result: Fit

# %%
exercise_hours=float(input('Enter Number of Exercise Hours'))
cal_intake=float(input('Enter number of calories consumed'))
pred_fu = model.predict([[exercise_hours, cal_intake]])
print(f'Exercise Hours: {exercise_hours}, Calories Intake: {cal_intake} → You are likely {pred_fu[0]}')
# Out:
# Enter Number of Exercise Hours 3.5
# Enter number of calories consumed 2500
# Exercise Hours: 3.5, Calories Intake: 2500.0 → You are likely Fit

# %%
import pandas as pd

# %%
df = pd.read_csv('fruit_data.csv')
df
# Out:
#    Weight  Size   Fruit
# 0     150   7.0   Apple
# 1     160   7.2   Apple
# 2     200   8.0  Orange
# 3     210   8.2  Orange
# 4     180   7.5       ?

# %%
X = df[['Weight','Size']]
y = df['Fruit']

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_fruit=pd.DataFrame([[120, 2]], columns=['Weight','Size'])
pred = model.predict(new_fruit)
print("Predicted Result:", pred[0])
# Out:
# Predicted Result: Apple

# %%
fruit_weight=float(input('Enter weight of frout in gm'))
fruit_size=float(input('Enter size of fruit in cm'))
our_fruit=pd.DataFrame([[fruit_weight, fruit_size]],columns=['Weight','Seize'])
pred_fruit = model.predict(our_fruit)
print(f'Fruit weight is {fruit_weight}, Fruit size is {fruit_size}. The fruit is likely a: {pred_fruit[0]}')
# Out:
# Enter weight of frout in gm 12
# Enter size of fruit in cm 34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 fruit_size=float(input('Enter size of fruit in cm'))
#       3 our_fruit=pd.DataFrame([[fruit_weight, fruit_size]],columns=['Weight','Seize'])
# ----> 4 pred_fruit = model.predict(our_fruit)
#       5 print(f'Fruit weight is {fruit_weight}, Fruit size is {fruit_size}. The fruit is likely a: {pred_fruit[0]}')
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/neighbors/_classification.py:274, in KNeighborsClassifier.predict(self, X)
#     271         return self.classes_[np.argmax(probabilities, axis=1)]
#     272     # In that case, we do not need the distances to perform
#     273     # the weighting so we do not compute them.
# --> 274     neigh_ind = self.kneighbors(X, return_distance=False)
#     275     neigh_dist = None
#     276 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/neighbors/_base.py:838, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     836         X = _check_precomputed(X)
#     837     else:
# --> 838         X = validate_data(
#     839             self,
#     840             X,
#     841             ensure_all_finite=ensure_all_finite,
#     842             accept_sparse="csr",
#     843             reset=False,
#     844             order="C",
#     845         )
#     847 n_samples_fit = self.n_samples_fit_
#     848 if n_neighbors > n_samples_fit:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)
#    2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Seize
# Feature names seen at fit time, yet now missing:
# - Size

# %%
fruit_weight=float(input('Enter weight of frout in gm'))
fruit_size=float(input('Enter size of fruit in cm'))
pred_fruit = model.predict([[fruit_weight, fruit_size]])
print(f'Fruit Weight is {fruit_weight}, Fruit size is: {cal_intake} The Fruit is likely an: {pred_fruit[0]}')
# Out:
# Enter weight of frout in gm 175
# Enter size of fruit in cm 4.6
# Fruit Weight is 175.0, Fruit size is: 2500.0 The Fruit is likely an: Apple
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Download student_grade.csv from GitHub.com
# # Predict a students' **grade level (A, B, or C)**
# # based on **hours studied** and **assignments completed**
# # using the K-Nearest Neighbors algorithm.

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('student_grade.csv')
df
# Out:
#    Hours_Studied  Assignments_Completed Grade
# 0            1.5                      1     C
# 1            2.0                      2     C
# 2            3.0                      3     B
# 3            4.0                      4     B
# 4            5.0                      5     A
# 5            6.0                      6     A

# %%
X = df[['Hours_Studied','Assignments_Completed']]
y = df['Grade']

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pre_grade = pd.DataFrame([[1.5, 1]], columns=['Hours_Studied', 'Assignments_Completed'])
pred = model.predict(pre_grade)
print("Predicted Grade:", pred[0])
# Out:
# Predicted Grade: C
