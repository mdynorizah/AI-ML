# %%
import matplotlib.pyplot as plt

# %%
products=['Laptop','IPad','HeadPhones','Keyboard']
weekly_sales=[400,200,600,150]
plt.bar(products,weekly_sales)
plt.title('Weekly Product Sales')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.show()

# %%
products=['Laptop','IPad','HeadPhones','Keyboard']
weekly_sales=[400,200,600,150]
plt.figure(figsize=(6,3))
bar_colors=['blue','red','green','yellow']
plt.bar(products, weekly_sales, color=bar_colors, width=0.5, edgecolor='black')   
plt.title('Weekly Product Sales')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # We have following dictionary
#     ##product_sales=('Laptop':750, 'Smart Phone': 650, 'Smart Watch': 400, 'Tablets':500, 'AC':400)
# # Represent this data using bar chart xlabel is ProductName (e.g.Laptop) and ylabel is sales value(e.g. 750)
#     ##use colors for bar
#     ##use appropriate Headings

# %%
products_sales = {'Laptop':750, 'SmartPhone':650, 'SmartWatch':400, 'Tablets':500}
products = list(products_sales.keys())
sales = list(products_sales.values())
bar_colors = ['blue', 'red', 'green', 'yellow']
plt.bar(products, weekly_sales, color=bar_colors, width=0.5, edgecolor='black')   
plt.title('Product Sales')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('patients.csv')
print(df.head())
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
age_counts = df['age'].value_counts().sort_index()  # use consistent name
plt.figure(figsize=(8, 15))
plt.bar(age_counts.index, age_counts.values, color='skyblue', width=0.5, edgecolor='orange')
plt.title('Number of Patients by Age')
plt.xlabel('Age')      # also fixed spelling: xlabel, not xlable
plt.ylabel('Number of Patients')
plt.show()

# %%
print(df['service'].value_counts())
# Out:
# service
# emergency           263
# surgery             254
# general_medicine    242
# ICU                 241
# Name: count, dtype: int64

# %%
avg_age_by_date = df.groupby('arrival_date')['age'].mean()
print(avg_age_by_date)
# Out:
# arrival_date
# 2025-01-02    30.000000
# 2025-01-03    61.500000
# 2025-01-04    33.000000
# 2025-01-05    27.000000
# 2025-01-06    27.333333
#                 ...
# 2025-12-27    79.500000
# 2025-12-28    26.000000
# 2025-12-29    46.666667
# 2025-12-30    50.833333
# 2025-12-31    62.750000
# Name: age, Length: 344, dtype: float64

# %%
df['arrival_date'] = pd.to_datetime(df['arrival_date'])
print(df['arrival_date'])                                  
avg_age_by_date = df.groupby('arrival_date')['age'].mean()
print(avg_age_by_date)
# Out:
# 0     2025-03-16
# 1     2025-12-13
# 2     2025-06-29
# 3     2025-10-12
# 4     2025-02-18
#          ...
# 995   2025-12-02
# 996   2025-11-18
# 997   2025-12-12
# 998   2025-02-08
# 999   2025-05-04
# Name: arrival_date, Length: 1000, dtype: datetime64[ns]
# arrival_date
# 2025-01-02    30.000000
# 2025-01-03    61.500000
# 2025-01-04    33.000000
# 2025-01-05    27.000000
# 2025-01-06    27.333333
#                 ...
# 2025-12-27    79.500000
# 2025-12-28    26.000000
# 2025-12-29    46.666667
# 2025-12-30    50.833333
# 2025-12-31    62.750000
# Name: age, Length: 344, dtype: float64

# %% [markdown]
# # Create a Bar plot - Average age of patients by Arrival Date

# %%
df['arrival_date']=pd.to_datetime(df['arrival_date'])
print(df['arrival_date'])
avg_age_by_date = df.groupby('arrival_date')['age'].mean()
print(avg_age_by_date)
# Out:
# 0     2025-03-16
# 1     2025-12-13
# 2     2025-06-29
# 3     2025-10-12
# 4     2025-02-18
#          ...
# 995   2025-12-02
# 996   2025-11-18
# 997   2025-12-12
# 998   2025-02-08
# 999   2025-05-04
# Name: arrival_date, Length: 1000, dtype: datetime64[ns]
# arrival_date
# 2025-01-02    30.000000
# 2025-01-03    61.500000
# 2025-01-04    33.000000
# 2025-01-05    27.000000
# 2025-01-06    27.333333
#                 ...
# 2025-12-27    79.500000
# 2025-12-28    26.000000
# 2025-12-29    46.666667
# 2025-12-30    50.833333
# 2025-12-31    62.750000
# Name: age, Length: 344, dtype: float64

# %%
df['arrival_date']=pd.to_datetime(df['arrival_date'])
avg_age_by_date = df.groupby('arrival_date')['age'].mean()
plt.figure(figsize=(10,5))
plt.bar(avg_age_by_date.index.astype(str),avg_age_by_date.values,color='skyblue',width=0.5,edgecolor='orange')
plt.title('Average Age of Patients by Arrival Date')
plt.xlabel('Arrival Date')
plt.ylabel('Average Age')
plt.xticks(rotation=45)
plt.show()

# %%
print(df.head())
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
print(df.groupby('service')['age'].min())
# Out:
# service
# ICU                 0
# emergency           0
# general_medicine    0
# surgery             0
# Name: age, dtype: int64

# %%
print(df['service'])
# Out:
# 0               surgery
# 1               surgery
# 2      general_medicine
# 3             emergency
# 4                   ICU
#              ...
# 995           emergency
# 996           emergency
# 997                 ICU
# 998                 ICU
# 999    general_medicine
# Name: service, Length: 1000, dtype: object

# %% [markdown]
# # Pie Chart
#     ##products=['Laptop', 'IPad','HeadPhones','Keyboard']
#     ##weekly_sales=[400,200,600,150]

# %%
products=['Laptop','IPad','HeadPhones','Keyboard']
sales=[400,200,600,150]
plt.figure(figsize=(7,7))
plt.pie(sales, labels=products)
# Out:
# ([<matplotlib.patches.Wedge at 0x11549c1a0>,
#   <matplotlib.patches.Wedge at 0x17513d590>,
#   <matplotlib.patches.Wedge at 0x17513d810>,
#   <matplotlib.patches.Wedge at 0x17513da90>],
#  [Text(0.6568744397048419, 0.882335520344982, 'Laptop'),
#   Text(-0.7548658746645874, 0.8001109368499268, 'IPad'),
#   Text(-0.549999888958152, -0.9526280082729147, 'HeadPhones'),
#   Text(1.0336617954935041, -0.37622239770798543, 'Keyboard')])

# %%
products=['Laptop','IPad','HeadPhones','Keyboard']
sales=[400,200,600,150]
plt.figure(figsize=(5,5))
plt.pie(sales, labels=products)
plt.title ('Product Weekly Sales Report')
plt.show()

# %%
plt.figure(figsize=(5,5))
products_sales = {'Laptop':750, 'SmartPhone':650, 'SmartWatch':400, 'Tablets':500, 'AC':400}
products = list(products_sales.keys())
sales = list(products_sales.values())
pie_colors = ['blue', 'red', 'green', 'yellow','pink']
plt.pie(sales, labels=products, colors=pie_colors, shadow=True)   
plt.title('Product Weekly Sales Report')
plt.show()

# %%
df=pd.read_csv('patients.csv')
print(df.head(5))
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
service_counts=df['service'].value_counts()
print(service_counts)
# Out:
# service
# emergency           263
# surgery             254
# general_medicine    242
# ICU                 241
# Name: count, dtype: int64

# %%
service_name=service_counts.index
print(service_name)
# Out:
# Index(['emergency', 'surgery', 'general_medicine', 'ICU'], dtype='object', name='service')

# %%
plt.pie(service_counts, labels=service_name, shadow=True)
plt.title('Distribution of Patients by Service',fontsize=20, fontweight='bold')
plt.show()

# %%
products_sales = {'Laptop':750, 'SmartPhone':650, 'SmartWatch':400, 'Tablets':500, 'AC':400}
products = list(products_sales.keys())
sales = list(products_sales.values())
plt.scatter(products,sales)
plt.title('Basic Product and Sales Representation')
plt.xlabel('products')
plt.ylabel('sales')
plt.grid('True')
plt.show()

# %%
players=['MSD','Rohit','Virat','Gill','Shami']
match1_score=[45,67,56,78,89]
match2_score=[55,78,40,80,97]
plt.figure(figsize=(8,5))
plt.scatter(players,match1_score,color='red',label='Match One', s=100)
plt.scatter(players,match2_score,color='green',label='Match Two', s=100, marker="x") 
plt.title('Comparision of Players in Two Matches')
plt.xlabel('Players')
plt.ylabel('Score')
plt.show()

# %%
players=['MSD','Rohit','Virat','Gill','Shami']
match1_score=[45,67,56,78,89]
match2_score=[55,78,40,80,97]
plt.figure(figsize=(8,5))
plt.scatter(players,match1_score,color='red',label='Match One', s=100)
plt.scatter(players,match2_score,color='green',label='Match Two', s=100, marker="x") 
plt.title('Comparision of Players in Two Matches')
plt.xlabel('Players')
plt.ylabel('Score')
plt.grid(True,linestyle='--',alpha=0.5)
plt.show()

# %%
players=['MSD','Rohit','Virat','Gill','Shami']
match1_score=[45,67,56,78,89]
match2_score=[55,78,40,80,97]
match3_score=[90,40,20,30,60]
plt.figure(figsize=(8,5))
plt.scatter(players,match1_score,color='red',label='Match One', s=100)
plt.scatter(players,match2_score,color='green',label='Match Two', s=100, marker="d") 
plt.scatter(players,match3_score,color='blue',label='Match Three', s=150, marker="p") 
plt.title('Comparision of Players in Three Matches')
plt.xlabel('Players')
plt.ylabel('Score')
plt.legend()
plt.grid(True,linestyle='--',alpha=0.5)
plt.show()

# %% [markdown]
# # Write a comparision that shows average calories burned for each workout type from final_data dataset

# %%
df=pd.read_csv('Final_data.csv')
avg_cal=df.groupby('Workout_Type')['Calories_Burned'].mean()
selected_index=avg_cal.index
selected_value=avg_cal.values
plt.scatter(selected_index, selected_value,color='red',label='Match One', s=100)
plt.title('Comparision of Workout and calories Burned')
plt.xlabel('Workout Type')
plt.ylabel('Calories Burned')
plt.grid(True,linestyle='--',alpha=0.5)
plt.show()

# %%
print(df['Calories_Burned'])
# Out:
# 0        1080.90
# 1        1809.91
# 2         802.26
# 3        1450.79
# 4        1166.40
#           ...
# 19995     761.61
# 19996    2303.13
# 19997    1468.80
# 19998     929.75
# 19999     861.84
# Name: Calories_Burned, Length: 20000, dtype: float64

# %%
avg_calories=df.groupby('Workout_Type')['Calories_Burned'].mean()
print(avg_calories)
# Out:
# Workout_Type
# Cardio      1211.544680
# HIIT        1652.533209
# Strength    1361.430459
# Yoga         897.107216
# Name: Calories_Burned, dtype: float64

# %% [markdown]
# # Create a bar chart using following data
# # we following libraries
#     ## python_lib=['Numpy','Pandas,'Matplotlib','Scikit-learn']
# # Liked by users as follows
#     ## liked_by=[5000,7000,9000,4000]
# # Create a vertical bar graph where each bar represents the value of python_lib respective liked by users
#     ## ever bar must have different color

# %%
python_lib=['Numpy','Pandas','Matplotlib','Scikit-learn']
num=[5000,7000,9000,4000]
plt.bar(python_lib,num)
plt.title('Python Library')
plt.xlabel('python_lib')
plt.ylabel('num')
plt.show()

# %%
python_lib=['Numpy','Pandas','Matplotlib','Scikit-learn']
num=[5000,7000,9000,4000]
bar_colors=['red','blue','green','black','purple']
plt.figure(figsize=(8,4))
plt.bar(python_lib,num,color=bar_colors,width=0.5,edgecolor='yellow')
plt.title('Python Library')
plt.xlabel('python_lib')
plt.ylabel('num')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.barh(python_lib,num,color=bar_colors)
plt.title('Python Library')
plt.show()
