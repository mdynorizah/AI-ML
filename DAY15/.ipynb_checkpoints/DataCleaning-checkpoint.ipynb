# %%
import pandas as pd

# %%
data={'Students':['Amit','Anam','Chi','Sam','Ravi','Jae'],
 'Marks':[85,None,65,75,None,55]}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Students  Marks
# 0     Amit   85.0
# 1     Anam    NaN
# 2      Chi   65.0
# 3      Sam   75.0
# 4     Ravi    NaN
# 5      Jae   55.0

# %%
df=pd.DataFrame(data)
print('Original Data')
df
# Out:
# Original Data
#   Students  Marks
# 0     Amit   85.0
# 1     Anam    NaN
# 2      Chi   65.0
# 3      Sam   75.0
# 4     Ravi    NaN
# 5      Jae   55.0

# %%
print('Missing Data')
print('Number of Missing values are:',df.isnull().sum())
# Out:
# Missing Data
# Number of Missing values are: Students    0
# Marks       2
# dtype: int64

# %%
average_marks=df['Marks'].mean()
print(average_marks)
# Out:
# 70.0

# %%
df.fillna(average_marks, inplace=True)

# %%
print('afer fillna() call')
df
# Out:
# afer fillna() call
#   Students  Marks
# 0     Amit   85.0
# 1     Anam   70.0
# 2      Chi   65.0
# 3      Sam   75.0
# 4     Ravi   70.0
# 5      Jae   55.0

# %% [markdown]
# # Let us see it, how we will use in our project

# %%
#fillna() example
students_data={'Name':['Amit','Anam','Chi','Sam','Ravi','Jae'],'Marks':[85,None,65,75,None,55]}
df=pd.DataFrame(students_data)
df
# Out:
#    Name  Marks
# 0  Amit   85.0
# 1  Anam    NaN
# 2   Chi   65.0
# 3   Sam   75.0
# 4  Ravi    NaN
# 5   Jae   55.0

# %%
df.fillna(df['Marks'].mean(),inplace=True)

# %%
df
# Out:
#    Name  Marks
# 0  Amit   85.0
# 1  Anam   70.0
# 2   Chi   65.0
# 3   Sam   75.0
# 4  Ravi   70.0
# 5   Jae   55.0

# %% [markdown]
# # dropna() example

# %%
students_data={'Name':['Amit','Anam','Chi','Sam','Ravi','Jae'],'Marks':[85,None,65,75,None,55]}
df=pd.DataFrame(students_data)
print('Original Data')
df
# Out:
# Original Data
#    Name  Marks
# 0  Amit   85.0
# 1  Anam    NaN
# 2   Chi   65.0
# 3   Sam   75.0
# 4  Ravi    NaN
# 5   Jae   55.0

# %%
df=df.dropna(subset=['Marks'])

# %%
print('Dataset after droma()')
df
# Out:
# Dataset after droma()
#    Name  Marks
# 0  Amit   85.0
# 2   Chi   65.0
# 3   Sam   75.0
# 5   Jae   55.0

# %%
students_data={'Name':['Amit','Anam','Chi','Sam','Ravi','Jae'],'Marks':[85,None,65,75,None,55]}
df=pd.DataFrame(students_data)
print('Original Data')
df
df=df.dropna()
df
# Out:
# Original Data
#    Name  Marks
# 0  Amit   85.0
# 2   Chi   65.0
# 3   Sam   75.0
# 5   Jae   55.0

# %%
df=df.dropna()
print('Dataset after droma()')
df
# Out:
# Dataset after droma()
#    Name  Marks
# 0  Amit   85.0
# 2   Chi   65.0
# 3   Sam   75.0
# 5   Jae   55.0

# %%
emp_data={
    "Name":['Sam','Ali','Chang','Xi','Viz','Suhail'],
    "Age":[35,None,25,20,24,None],
    "Salary":[50000,40000,50000,40000,None,None],
    }
df=pd.DataFrame(emp_data)
print('Original Data')
df
# Out:
# Original Data
#      Name   Age   Salary
# 0     Sam  35.0  50000.0
# 1     Ali   NaN  40000.0
# 2   Chang  25.0  50000.0
# 3      Xi  20.0  40000.0
# 4     Viz  24.0      NaN
# 5  Suhail   NaN      NaN

# %%
print(df.isnull().sum())
# Out:
# Name      0
# Age       2
# Salary    2
# dtype: int64

# %%
df_drop=df.dropna()
df_drop
# Out:
#     Name   Age   Salary
# 0    Sam  35.0  50000.0
# 2  Chang  25.0  50000.0
# 3     Xi  20.0  40000.0

# %%
df_drop_salary=df.dropna(subset=['Salary'])
df_drop_salary
# Out:
#     Name   Age   Salary
# 0    Sam  35.0  50000.0
# 1    Ali   NaN  40000.0
# 2  Chang  25.0  50000.0
# 3     Xi  20.0  40000.0

# %%
df_drop_age=df.dropna(subset=['Age'])
df_drop_age
# Out:
#     Name   Age   Salary
# 0    Sam  35.0  50000.0
# 2  Chang  25.0  50000.0
# 3     Xi  20.0  40000.0
# 4    Viz  24.0      NaN

# %%
#fillna example
df_fillna=df.fillna(df['Age'].mean(),inplace=True)
df_fillna=df.fillna(df['Salary'].mean(),inplace=True)
df
# Out:
#      Name   Age   Salary
# 0     Sam  35.0  50000.0
# 1     Ali  26.0  40000.0
# 2   Chang  25.0  50000.0
# 3      Xi  20.0  40000.0
# 4     Viz  24.0     26.0
# 5  Suhail  26.0     26.0

# %%
#fillna example
emp_data={
    "Name":['Sam','Ali','Chang','Xi','Viz','Suhail'],
    "Age":[35,None,25,20,24,None],
    "Salary":[50000,40000,50000,40000,None,None],
    }
df=pd.DataFrame(emp_data)
df.fillna({'Age':df['Age'].mean(),'Salary':df['Salary'].mean()},inplace=True)
df
# Out:
#      Name   Age   Salary
# 0     Sam  35.0  50000.0
# 1     Ali  26.0  40000.0
# 2   Chang  25.0  50000.0
# 3      Xi  20.0  40000.0
# 4     Viz  24.0  45000.0
# 5  Suhail  26.0  45000.0

# %% [markdown]
# # download students_performance_dirty.csv
# ## find out number of missing data
# ## drop row where gender is missing
# ## fill study_hours with average study_hours

# %%
df = pd.read_csv('students_performance_dirty.csv')
df
# Out:
#     gender  study_hours  attendance_pct  math_score  reading_score  \
# 0     male          1.7            83.6        62.0           91.0
# 1      NaN          2.6            91.2        82.0           60.0
# 2   female          2.9            97.5        69.0           57.0
# 3   female          4.8            85.7        78.0           62.0
# 4     male          3.9           -10.0        64.0           95.0
# 5     male          1.4            93.7        77.0           72.0
# 6     male          NaN            87.1        95.0           78.0
# 7    femle          NaN            70.6        59.0           70.0
# 8   female          2.7            74.7        68.0           71.0
# 9   female          4.2            92.4        63.0           66.0
# 10    male          4.7            67.9        94.0           73.0
# 11     NaN          4.6            86.2        63.0           78.0
# 12   femle          NaN            95.0        59.0           92.0
# ...

# %%
print(df.isnull().sum())
# Out:
# gender            8
# study_hours       8
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64

# %%
df_drop_gender=df.dropna(subset=['gender'])
df_drop_gender
# Out:
#     gender  study_hours  attendance_pct  math_score  reading_score  \
# 0     male          1.7            83.6        62.0           91.0
# 2   female          2.9            97.5        69.0           57.0
# 3   female          4.8            85.7        78.0           62.0
# 4     male          3.9           -10.0        64.0           95.0
# 5     male          1.4            93.7        77.0           72.0
# 6     male          NaN            87.1        95.0           78.0
# 7    femle          NaN            70.6        59.0           70.0
# 8   female          2.7            74.7        68.0           71.0
# 9   female          4.2            92.4        63.0           66.0
# 10    male          4.7            67.9        94.0           73.0
# 12   femle          NaN            95.0        59.0           92.0
# 13    male          NaN            86.5        61.0           50.0
# 14    male          3.9            79.0        68.0           91.0
# ...

# %%
df.fillna({'study_hours': df['study_hours'].mean()}, inplace=True)

# %%
print('Number of Missing values are:',df.isnull().sum())
# Out:
# Number of Missing values are: gender            8
# study_hours       0
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64
