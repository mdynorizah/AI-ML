# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Netflix Dataset.csv')
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
df=df.dropna(subset=['release_year'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('Netflix Dataset.csv')
df=df.dropna(subset=['Release_Date'])
df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce')
plt.figure(figsize=(8,5))
plt.hist(df['Release_Date'],bins=100,color='green', edgecolor='yellow', alpha=0.8)
plt.title('Netflix Released Titles by Year')
plt.xlabel('Release Date')
plt.ylabel('Number of Titles')
plt.grid(color='blue',linestyle='--',linewidth=0.7)
plt.tight_layout()
plt.savefig('netflix_bar.pdf',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Use Netflix_Dataset.csv dataset
#   ## print how many Movies and TV Shows are available on Netflix
#   ## Display Movies and TV Shows proportion in a pie plot
#   ## Save file as pdf

# %%
df=df.dropna(subset=['Type'])

# %%
type_counts=df['Type'].value_counts()
print(type_counts)
# Out:
# Type
# Documentaries                                                                      334
# Stand-Up Comedy                                                                    321
# Dramas, International Movies                                                       320
# Comedies, Dramas, International Movies                                             243
# Dramas, Independent Movies, International Movies                                   215
#                                                                                   ...
# Anime Series, Crime TV Shows, TV Thrillers                                           1
# Crime TV Shows, Romantic TV Shows, Spanish-Language TV Shows                         1
# Crime TV Shows, International TV Shows, Reality TV                                   1
# International Movies, Romantic Movies, Sci-Fi & Fantasy                              1
# International TV Shows, Spanish-Language TV Shows, Stand-Up Comedy & Talk Shows      1
# ...

# %%
plt.figure(figsize=(7,7))
plt.pie(type_counts,
        labels=type_counts.index,
        colors=['orange','green'],
        autopct='%1.2f%%', startangle=140, shadow=True, explode=(0.05,0.05)
       )
plt.title('Netflix Movies and TV Shows Distribution')
plt.grid(axis='y',color='lightblue',linestyle='--',linewidth=0.7)
plt.tight_layout()
plt.legend(title='Movies and Shows')
plt.savefig('netflix_pieplot.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.figure(figsize=(7,7))
# ----> 2 plt.pie(type_counts,
#       3         labels=type_counts.index,
#       4         colors=['orange','green'],
#       5         autopct='%1.2f%%', startangle=140, shadow=True, explode=(0.05,0.05)
#       6        )
#       7 plt.title('Netflix Movies and TV Shows Distribution')
#       8 plt.grid(axis='y',color='lightblue',linestyle='--',linewidth=0.7)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
# ...
